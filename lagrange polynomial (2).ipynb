# %%
import random
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting input of the points

# %%
n=10
x=[]
y=[]
for i in range(n):
    x.append(random.randint(-100, 100))
x=sorted(x)

for i in range(len(x)):
    X=x[i]
    y.append(X**2)
print(x,y)
# Out:
# [-99, -71, -51, -41, -36, -8, 29, 39, 91, 93] [9801, 5041, 2601, 1681, 1296, 64, 841, 1521, 8281, 8649]

# %% [markdown]
# ## Function for Lagrange Polynomial

# %%
def lagpoly(x,y,a):
    f=0
    for i in range(len(x)):
        sop=1
        for j in range(len(x)):
            if x[i]!=x[j]:
                sop=sop*(a-x[j])/(x[i]-x[j])
        f=f+y[i]*sop
    return(f)

# %%
xAxis=np.arange(-35, +35)
yAxis=[]
for i in range(len(xAxis)):
    yAxis.append(lagpoly(x,y,xAxis[i]))

#for i in (xAxis):
print(yAxis)
# Out:
# [1224.9999999999995, 1156.0000000000005, 1088.9999999999998, 1023.9999999999994, 961.000000000001, 900.0, 840.9999999999984, 784.0000000000001, 729.0000000000007, 676.0000000000018, 625.0000000000007, 575.9999999999992, 528.9999999999978, 483.99999999999864, 440.99999999999943, 400.00000000000136, 361.00000000000114, 323.9999999999992, 288.9999999999994, 255.99999999999966, 224.99999999999974, 196.00000000000028, 168.99999999999991, 143.99999999999997, 121.00000000000028, 100.00000000000009, 81.00000000000021, 64.0, 49.00000000000005, 35.999999999999176, 24.999999999999773, 15.99999999999946, 9.000000000000298, 4.000000000000334, 0.9999999999988631, 6.679101716144942e-13, 0.9999999999987779, 4.00000000000054, 9.000000000003467, 15.999999999998536, 25.00000000000132, 36.00000000000537, 48.99999999999923, 64.00000000000003, 80.99999999999656, 100.00000000000205, 120.99999999999824, 143.99999999999946, 169.00000000000307, 196.00000000000415, 224.99999999999974, 255.99999999999798, 288.9999999999983, 324.00000000000193, 360.99999999999864, 400.00000000000125, 441.0000000000021, 484.0000000000001, 529.0000000000013, 576.0000000000003, 625.0000000000005, 675.9999999999998, 729.0, 784.0000000000005, 841.0, 899.9999999999999, 961.0000000000006, 1024.0000000000002, 1089.000000000001, 1155.9999999999993]

# %%
plt.plot(xAxis ,yAxis)
plt.show()
plt.plot(x ,y)
plt.show()
